# %%
from main import app
print("before openapi")
schema = app.openapi()
print("after openapi", len(schema.get("paths", {})))
PY
# Out:
# before openapi
# after openapi 9
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 from main import app
#       2 print("before openapi")
#       3 schema = app.openapi()
#       4 print("after openapi", len(schema.get("paths", {})))
# ----> 5 PY
#
# NameError: name 'PY' is not defined
